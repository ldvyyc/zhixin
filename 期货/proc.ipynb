# %%
import pandas as pd

# %%
# read data.xlsx, sheet is Y_2023
df = pd.read_excel('data.xlsx', sheet_name='Y_2023')
df
# Out:
# /Users/ldvyyc/miniconda3/lib/python3.9/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
#     Unnamed: 0 Unnamed: 1     Loss   LNum      Win  WNum        Amount  \
# 0          NaT        NaN      NaN    NaN      NaN   NaN           NaN
# 1   2023-03-31          Y   -240.0    3.0   4200.0  13.0  3.350340e+06
# 2   2023-04-03          Y  -3160.0   19.0  12560.0  27.0  1.228058e+07
# 3   2023-04-04          Y -17500.0   67.0    460.0   7.0  2.347530e+07
# 4   2023-04-06          Y -13040.0   28.0   1100.0   5.0  2.992088e+07
# ..         ...        ...      ...    ...      ...   ...           ...
# 120 2023-09-22          Y  -2320.0    8.0   7800.0  41.0  2.245915e+09
# 121 2023-09-25          Y -90740.0  146.0  20900.0  73.0  2.271117e+09
# 122 2023-09-26          Y  -3120.0   15.0  20280.0  54.0  2.283873e+09
# ...

# %%
# delete first row
df = df.drop(0)
df
# Out:
#     Unnamed: 0 Unnamed: 1     Loss   LNum      Win  WNum        Amount  \
# 1   2023-03-31          Y   -240.0    3.0   4200.0  13.0  3.350340e+06
# 2   2023-04-03          Y  -3160.0   19.0  12560.0  27.0  1.228058e+07
# 3   2023-04-04          Y -17500.0   67.0    460.0   7.0  2.347530e+07
# 4   2023-04-06          Y -13040.0   28.0   1100.0   5.0  2.992088e+07
# 5   2023-04-07          Y  -9980.0   27.0  25440.0  32.0  3.928494e+07
# ..         ...        ...      ...    ...      ...   ...           ...
# 120 2023-09-22          Y  -2320.0    8.0   7800.0  41.0  2.245915e+09
# 121 2023-09-25          Y -90740.0  146.0  20900.0  73.0  2.271117e+09
# 122 2023-09-26          Y  -3120.0   15.0  20280.0  54.0  2.283873e+09
# 123 2023-09-27          Y -14080.0   60.0   7560.0  16.0  2.293801e+09
# 124 2023-09-28          Y  -9280.0   19.0      NaN   NaN  2.295339e+09
#
#       Volume      Avg    CumLoss     CumWin  Psh      PnL     CumPnL  \
# ...

# %%
# rename first column to 'Date'
df = df.rename(columns={df.columns[0]: 'Date'})
df = df.rename(columns={df.columns[1]: 'Type'})
df
# Out:
#           Date Type     Loss   LNum      Win  WNum        Amount   Volume  \
# 1   2023-03-31    Y   -240.0    3.0   4200.0  13.0  3.350340e+06     41.0
# 2   2023-04-03    Y  -3160.0   19.0  12560.0  27.0  1.228058e+07    149.0
# 3   2023-04-04    Y -17500.0   67.0    460.0   7.0  2.347530e+07    283.0
# 4   2023-04-06    Y -13040.0   28.0   1100.0   5.0  2.992088e+07    360.0
# 5   2023-04-07    Y  -9980.0   27.0  25440.0  32.0  3.928494e+07    473.0
# ..         ...  ...      ...    ...      ...   ...           ...      ...
# 120 2023-09-22    Y  -2320.0    8.0   7800.0  41.0  2.245915e+09  28625.0
# 121 2023-09-25    Y -90740.0  146.0  20900.0  73.0  2.271117e+09  28942.0
# 122 2023-09-26    Y  -3120.0   15.0  20280.0  54.0  2.283873e+09  29102.0
# 123 2023-09-27    Y -14080.0   60.0   7560.0  16.0  2.293801e+09  29226.0
# 124 2023-09-28    Y  -9280.0   19.0      NaN   NaN  2.295339e+09  29245.0
#
#          Avg    CumLoss     CumWin  Psh      PnL     CumPnL  TradeVol  \
# ...

# %%
# drop last column
df = df.drop(df.columns[-1], axis=1)
df
# Out:
#           Date Type     Loss   LNum      Win  WNum        Amount   Volume  \
# 1   2023-03-31    Y   -240.0    3.0   4200.0  13.0  3.350340e+06     41.0
# 2   2023-04-03    Y  -3160.0   19.0  12560.0  27.0  1.228058e+07    149.0
# 3   2023-04-04    Y -17500.0   67.0    460.0   7.0  2.347530e+07    283.0
# 4   2023-04-06    Y -13040.0   28.0   1100.0   5.0  2.992088e+07    360.0
# 5   2023-04-07    Y  -9980.0   27.0  25440.0  32.0  3.928494e+07    473.0
# ..         ...  ...      ...    ...      ...   ...           ...      ...
# 120 2023-09-22    Y  -2320.0    8.0   7800.0  41.0  2.245915e+09  28625.0
# 121 2023-09-25    Y -90740.0  146.0  20900.0  73.0  2.271117e+09  28942.0
# 122 2023-09-26    Y  -3120.0   15.0  20280.0  54.0  2.283873e+09  29102.0
# 123 2023-09-27    Y -14080.0   60.0   7560.0  16.0  2.293801e+09  29226.0
# 124 2023-09-28    Y  -9280.0   19.0      NaN   NaN  2.295339e+09  29245.0
#
#          Avg    CumLoss     CumWin  Psh      PnL     CumPnL  TradeVol  \
# ...

# %%
df.to_csv('Y_2023.csv', index=False)

# %%
df = pd.read_csv('Y_2023.csv')
df
# Out:
#            Date Type     Loss   LNum      Win  WNum        Amount   Volume  \
# 0    2023-03-31    Y   -240.0    3.0   4200.0  13.0  3.350340e+06     41.0
# 1    2023-04-03    Y  -3160.0   19.0  12560.0  27.0  1.228058e+07    149.0
# 2    2023-04-04    Y -17500.0   67.0    460.0   7.0  2.347530e+07    283.0
# 3    2023-04-06    Y -13040.0   28.0   1100.0   5.0  2.992088e+07    360.0
# 4    2023-04-07    Y  -9980.0   27.0  25440.0  32.0  3.928494e+07    473.0
# ..          ...  ...      ...    ...      ...   ...           ...      ...
# 119  2023-09-22    Y  -2320.0    8.0   7800.0  41.0  2.245915e+09  28625.0
# 120  2023-09-25    Y -90740.0  146.0  20900.0  73.0  2.271117e+09  28942.0
# 121  2023-09-26    Y  -3120.0   15.0  20280.0  54.0  2.283873e+09  29102.0
# 122  2023-09-27    Y -14080.0   60.0   7560.0  16.0  2.293801e+09  29226.0
# 123  2023-09-28    Y  -9280.0   19.0      NaN   NaN  2.295339e+09  29245.0
#
# ...

# %%
df.describe()
# Out:
#                 Loss        LNum            Win        WNum        Amount  \
# count     120.000000  120.000000     119.000000  119.000000  1.240000e+02
# mean   -23126.666667   55.358333   34035.462185   67.075630  1.021643e+09
# std     25758.831767   41.667511   35670.035988   45.230888  6.916004e+08
# min   -153160.000000    2.000000      80.000000    1.000000  3.350340e+06
# 25%    -29190.000000   24.000000   10820.000000   35.000000  4.023064e+08
# 50%    -12830.000000   46.500000   22780.000000   61.000000  9.912084e+08
# 75%     -7420.000000   74.500000   44690.000000   86.500000  1.534675e+09
# max       -80.000000  264.000000  249820.000000  280.000000  2.295339e+09
#
#              Volume          Avg       CumLoss        CumWin  Psh  \
# count    124.000000   124.000000  1.240000e+02  1.240000e+02  0.0
# mean   13348.564516  7850.681774 -1.252502e+06  1.842759e+06  NaN
# std     8863.730077   450.181870  8.433260e+05  1.271276e+06  NaN
# ...

# %%
# 对df进行描述性分析，并画出图表
import matplotlib.pyplot as plt
import pandas as pd
data = pd.read_csv('Y_2023.csv')

# %%
# Plotting TradeVol and Opening in one figure
fig, ax1 = plt.subplots(figsize=(10, 5))

ax1.plot(data['Date'], data['TradeVol'], label='TradeVol', color='blue')
ax1.set_xlabel('Date')
ax1.set_ylabel('TradeVol', color='blue')
ax1.tick_params(axis='y', labelcolor='blue')

ax2 = ax1.twinx()
ax2.plot(data['Date'], data['Opening'], label='Opening', color='red')
ax2.set_ylabel('Opening', color='red')
ax2.tick_params(axis='y', labelcolor='red')

plt.title('Trade Number and Opening Number over Time')
plt.show()

# Plotting LPsh, WPsh, and WPsh/LPsh in one figure
fig, ax1 = plt.subplots(figsize=(10, 5))

ax1.plot(data['Date'], data['LPsh'], label='LPsh', color='green')
ax1.set_xlabel('Date')
ax1.set_ylabel('LPsh', color='green')
ax1.tick_params(axis='y', labelcolor='green')

ax2 = ax1.twinx()
ax2.plot(data['Date'], data['WPsh'], label='WPsh', color='blue')
ax2.set_ylabel('WPsh', color='blue')
ax2.tick_params(axis='y', labelcolor='blue')

# Calculating and plotting WPsh/LPsh
wpsh_lpsh_ratio = data['WPsh'] / data['LPsh']
ax3 = ax1.twinx()
ax3.spines['right'].set_position(('outward', 60))
ax3.plot(data['Date'], wpsh_lpsh_ratio, label='WPsh/LPsh', color='red', linestyle='dashed')
ax3.set_ylabel('WPsh/LPsh', color='red')
ax3.tick_params(axis='y', labelcolor='red')

plt.title('LPsh, WPsh, and WPsh/LPsh over Time')
plt.show()

# %%
tradevol_opening_diff = data['TradeVol'] - data['Opening']

# %%
# Plotting Opening and TradeVol-Opening in one figure
plt.figure(figsize=(10, 5))
plt.plot(data['Date'], data['Opening'], label='Opening', color='green')
plt.plot(data['Date'], tradevol_opening_diff, label='TradeVol-Opening', color='red', linestyle='dashed')

plt.xlabel('Date')
plt.ylabel('Value')
plt.title('Opening Num and TradeVol-Opening Difference over Time')
plt.legend()
plt.show()
